# %%
import cv2
import pandas as pd
import random
import matplotlib.pyplot as plt

# %%
#Pick random numbers between 0-900
x = random.choice(range(0, 900))
y = random.choice(range(0, 900))
z = random.choice(range(0, 900))

# %%
df = pd.read_csv("../data/performance_data.csv")
game_id = df['game_id']

# %%
im_1 = "../data/extracted_images/"+game_id[x] + "/start_frame.png"
im_2 = "../data/extracted_images/"+game_id[y] + "/start_frame.png"
im_3 = "../data/extracted_images/"+game_id[z] + "/start_frame.png"

# %%
img1 = cv2.imread(im_1)
img2 = cv2.imread(im_2)
img3 = cv2.imread(im_1)
plt.figure(1, figsize=(100, 10))
plt.subplot(211)
plt.imshow(img1)
plt.subplot(212)
plt.imshow(img3)
plt.show()

# %%
w = 10
h = 10
fig = plt.figure(figsize=(3, 1))
columns = 4
rows = 5
for i in range(3):
    fig.add_subplot(rows, columns, i)
    plt.imshow(img1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 6>()
#       5 rows = 5
#       6 for i in range(3):
# ----> 7     fig.add_subplot(rows, columns, i)
#       8     plt.imshow(img1)
#       9 plt.show()
#
# File ~/.conda/envs/10x/lib/python3.10/site-packages/matplotlib/figure.py:772, in FigureBase.add_subplot(self, *args, **kwargs)
#     769         args = tuple(map(int, str(args[0])))
#     770     projection_class, pkw = self._process_projection_requirements(
#     771         *args, **kwargs)
# --> 772     ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     773     key = (projection_class, pkw)
#     774 return self._add_axes_internal(ax, key)
#
# File ~/.conda/envs/10x/lib/python3.10/site-packages/matplotlib/axes/_subplots.py:36, in SubplotBase.__init__(self, fig, *args, **kwargs)
# ...
